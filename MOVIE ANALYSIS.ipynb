# %% [markdown]
# # Innomatics Reasearch Labs Hackathon

# %%
# About the Dataset
# This dataset contains information about the top 1000 highest grossing hollywood films. It is up to date as of 10th January 2022.
# This data has been scraped from multiple sites and has been added together for performing various data operations. The data has been taken from imdb, rotten tomatoes and many other sites.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing DataFrame

# %%
df=pd.read_csv("data.csv")
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %% [markdown]
# ## Drop Unnecessary Column

# %%
df.drop(["Unnamed: 0"], axis = 1,inplace=True)

# %% [markdown]
# ## Renaming The Columns

# %%
df.rename(columns = {'Release Date':'Release_Date'}, inplace = True)

# %%
df.rename(columns = {'Domestic Sales (in $)':'Domestic_Sales_In_Dollar'}, inplace = True)

# %%
df.rename(columns = {'International Sales (in $)':'International_Sales_In_Dollar'}, inplace = True)

# %%
df.rename(columns = {'World Sales (in $)':'World_Sales_In_Dollar'}, inplace = True)

# %%
df.rename(columns = {'Movie Runtime':'Movie_Runtime'}, inplace = True)

# %% [markdown]
# ## Top 5 rows

# %%
df.head(5)
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                               Black Panther (2018)
# 4                      Avengers: Infinity War (2018)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                            Distributor       Release_Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
# 2                Twentieth Century Fox  December 16, 2009
# 3  Walt Disney Studios Motion Pictures                NaN
# ...

# %% [markdown]
# ## Last 5 rows

# %%
df.tail(5)
# Out:
#                                   Title  \
# 913                 The Notebook (2004)
# 914    Jimmy Neutron: Boy Genius (2001)
# 915                Eat Pray Love (2010)
# 916  The Texas Chainsaw Massacre (2003)
# 917                    Zookeeper (2011)
#
#                                             Movie Info  \
# 913  A poor yet passionate young man falls in love ...
# 914  An eight-year-old boy genius and his friends m...
# 915  A married woman realizes how unhappy her marri...
# 916  After picking up a traumatized young hitchhike...
# 917  A group of zoo animals decide to break their c...
#
#                            Distributor       Release_Date  \
# 913                    New Line Cinema      June 25, 2004
# 914                 Paramount Pictures  December 21, 2001
# 915  Sony Pictures Entertainment (SPE)    August 13, 2010
# 916                    New Line Cinema   October 17, 2003
# 917  Sony Pictures Entertainment (SPE)       July 6, 2011
#
# ...

# %% [markdown]
# ## No.of rows and column in the dataframe

# %%
df.shape
# Out:
# (918, 10)

# %% [markdown]
# ## Information Of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Title                          918 non-null    object
#  1   Movie Info                     918 non-null    object
#  2   Distributor                    918 non-null    object
#  3   Release_Date                   800 non-null    object
#  4   Domestic_Sales_In_Dollar       918 non-null    int64
#  5   International_Sales_In_Dollar  918 non-null    int64
#  6   World_Sales_In_Dollar          918 non-null    int64
#  7   Genre                          918 non-null    object
#  8   Movie_Runtime                  918 non-null    object
#  9   License                        744 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 71.8+ KB

# %% [markdown]
# ## Statistics of the dataframe

# %%
df.describe(include="all")
# Out:
#                                                     Title  \
# count                                                 918
# unique                                                918
# top     Star Wars: Episode VII - The Force Awakens (2015)
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                Movie Info   Distributor  \
# count                                                 918           918
# unique                                                918            34
# ...

# %% [markdown]
# ## Checking Null Values

# %%
df.isnull().sum()
# Out:
# Title                              0
# Movie Info                         0
# Distributor                        0
# Release_Date                     118
# Domestic_Sales_In_Dollar           0
# International_Sales_In_Dollar      0
# World_Sales_In_Dollar              0
# Genre                              0
# Movie_Runtime                      0
# License                          174
# dtype: int64

# %% [markdown]
# ## Plot to show null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Drop duplicates and null values

# %%
df.drop_duplicates()
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 3                                 Black Panther (2018)
# 4                        Avengers: Infinity War (2018)
# ..                                                 ...
# 913                                The Notebook (2004)
# 914                   Jimmy Neutron: Boy Genius (2001)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %%
df.dropna(subset = ["Release_Date","License"], inplace=True)

# %% [markdown]
# ## Checking for null values

# %%
df.isnull().sum()
# Out:
# Title                            0
# Movie Info                       0
# Distributor                      0
# Release_Date                     0
# Domestic_Sales_In_Dollar         0
# International_Sales_In_Dollar    0
# World_Sales_In_Dollar            0
# Genre                            0
# Movie_Runtime                    0
# License                          0
# dtype: int64

# %% [markdown]
# ## Final dataframe free from null values

# %%
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 6                                       Titanic (1997)
# 7                                Jurassic World (2015)
# ..                                                 ...
# 911                     While You Were Sleeping (1995)
# 913                                The Notebook (2004)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 6    A seventeen-year-old aristocrat falls in love ...
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## plot showing correlation between Data

# %%
corr = df.corr()
f,ax = plt.subplots(figsize=(20, 15))
sns.heatmap(df.corr(), annot=True, fmt= '.1f',ax=ax, cmap="rainbow")
sns.set(font_scale=1.25)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.countplot(x ='Distributor', data = df) 
plt.xticks(rotation='90')
plt.title('Count plot for Distrubutor',fontsize=30)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x ='License', data = df) 
plt.title('Count plot for License',fontsize=30)
plt.show()

# %% [markdown]
# ## Type of Genre

# %%
Type_genre=df['Genre'].value_counts()
Type_genre
# Out:
# ['Action', 'Adventure', 'Sci-Fi']                                   51
# ['Comedy']                                                          31
# ['Comedy', 'Romance']                                               28
# ['Action', 'Adventure', 'Thriller']                                 22
# ['Comedy', 'Drama', 'Romance']                                      21
#                                                                     ..
# ['Comedy', 'Drama', 'Family', 'Fantasy']                             1
# ['Action', 'Adventure', 'Comedy', 'Family', 'Mystery', 'Sci-Fi']     1
# ['Adventure', 'Animation', 'Drama', 'Family', 'Fantasy']             1
# ['Comedy', 'Drama', 'Fantasy', 'Romance']                            1
# ['Comedy', 'Family', 'Fantasy', 'Romance']                           1
# Name: Genre, Length: 257, dtype: int64

# %% [markdown]
# ## Pie charting showing Top 20 Genre on basis of count

# %%
cmap = plt.get_cmap('Pastel1')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

df['Genre'].value_counts(ascending=False).head(20).plot(kind='pie', subplots=True,autopct='%1.1f%%', figsize=(15,15), colors=colors)
plt.title('Pie Chart For  Top 20 Genre on basis of count')
# Out:
# Text(0.5, 1.0, 'Pie Chart For  Top 20 Genre on basis of count')

# %%
#Top 10 Genre disliked by People
cmap = plt.get_cmap('Pastel1')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df['Genre'].value_counts().head(10).plot(kind='bar', figsize=(20,10), color=colors)

plt.title('Bar Chart showing top count Genre')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing top count Genre')

# %% [markdown]
# # Data analysis

# %%
# unit conversion
df["Domestic_Sales_In_Dollar"]=df["Domestic_Sales_In_Dollar"]/1000000

# %%
df["International_Sales_In_Dollar"]=df["International_Sales_In_Dollar"]/1000000

# %%
df["World_Sales_In_Dollar"]=df["World_Sales_In_Dollar"]/1000000

# %%
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 6                                       Titanic (1997)
# 7                                Jurassic World (2015)
# ..                                                 ...
# 911                     While You Were Sleeping (1995)
# 913                                The Notebook (2004)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 6    A seventeen-year-old aristocrat falls in love ...
# ...

# %% [markdown]
# # Pairplot

# %%
plt.figure(figsize  =(20,215))
sns.pairplot(df)
plt.show()

# %%
df1=df[['Title','World_Sales_In_Dollar']]
df1.sort_values(by=['World_Sales_In_Dollar'],ascending=False)
# Out:
#                                                  Title  World_Sales_In_Dollar
# 2                                        Avatar (2009)            2847.246203
# 1                             Avengers: Endgame (2019)            2797.501328
# 6                                       Titanic (1997)            2201.647264
# 0    Star Wars: Episode VII - The Force Awakens (2015)            2069.521700
# 7                                Jurassic World (2015)            1670.516444
# ..                                                 ...                    ...
# 752                                          42 (2013)              97.470701
# 783                            Think Like a Man (2012)              96.070507
# 848       Anchorman: The Legend of Ron Burgundy (2004)              90.709367
# 874                          I Can Only Imagine (2018)              86.086881
# 888               Star Trek: The Motion Picture (1979)              82.604699
#
# [744 rows x 2 columns]

# %%
#Top 10 most world sales movies
cmap = plt.get_cmap('tab20b')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df1.sort_values(by=['World_Sales_In_Dollar'],ascending=False).head(10).plot(x="Title",kind='bar', figsize=(20,10), color=colors)

plt.title('Bar Chart world Sales in Dollar')
# Out:
# Text(0.5, 1.0, 'Bar Chart world Sales in Dollar')

# %%
df2=df[['Title','Domestic_Sales_In_Dollar']]
df2.sort_values(by=['Domestic_Sales_In_Dollar'],ascending=False)
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 6                                       Titanic (1997)
# 7                                Jurassic World (2015)
# ..                                                 ...
# 911                     While You Were Sleeping (1995)
# 913                                The Notebook (2004)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#      Domestic_Sales_In_Dollar
# 0                  936.662225
# 1                  858.373000
# 2                  760.507625
# 6                  659.363944
# 7                  652.385625
# ..                        ...
# 911                 81.057016
# 913                 81.001787
# ...

# %%
##Top 10 most domestic sales movies
cmap = plt.get_cmap('prism')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df2.sort_values(by=['Domestic_Sales_In_Dollar'],ascending=False).head(10).plot(x="Title",kind='bar', figsize=(20,10), color=colors)

plt.title('Top 5 Domestic Movie Sale')
# Out:
# Text(0.5, 1.0, 'Top 5 Domestic Movie Sale')

# %%
df3=df[['Title','International_Sales_In_Dollar']]
df3.sort_values(by=['International_Sales_In_Dollar'],ascending=False)
# Out:
#                                                  Title  \
# 2                                        Avatar (2009)
# 1                             Avengers: Endgame (2019)
# 6                                       Titanic (1997)
# 54                                    Furious 7 (2015)
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# ..                                                 ...
# 785                          Heaven Is for Real (2014)
# 848       Anchorman: The Legend of Ron Burgundy (2004)
# 783                            Think Like a Man (2012)
# 874                          I Can Only Imagine (2018)
# 752                                          42 (2013)
#
#      International_Sales_In_Dollar
# 2                      2086.738578
# 1                      1939.128328
# 6                      1542.283320
# 54                     1162.334379
# 0                      1132.859475
# ..                             ...
# 785                      10.539459
# ...

# %%
#Top 10 most international sales movies
cmap = plt.get_cmap('Accent')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df3.sort_values(by=['International_Sales_In_Dollar'],ascending=False).head(10).plot(x="Title",kind='bar', figsize=(20,10), color=colors)

plt.title('Top 5 International Movie Sale')
# Out:
# Text(0.5, 1.0, 'Top 5 International Movie Sale')

# %% [markdown]
# ## Line ploting showing Domestic ,International and World Sales

# %%
data=df[["Domestic_Sales_In_Dollar","International_Sales_In_Dollar","World_Sales_In_Dollar"]]
import matplotlib.pyplot as plt

ax=data.plot(color=('blue','green','red'),figsize=(25,25),label="sales")
plt.legend(loc='upper left')
plt.xlabel('Month Number')

plt.title('Sales data ')
# Out:
# Text(0.5, 1.0, 'Sales data ')

# %% [markdown]
# ## Distplot showing Different Sales

# %%
plt.figure(figsize=(15, 8))
sns.distplot(df['World_Sales_In_Dollar'], bins=50)
plt.show()
# Out:
# D:\APP\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 8))
sns.distplot(df['Domestic_Sales_In_Dollar'], bins=50)
plt.show()
# Out:
# D:\APP\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 8))
sns.distplot(df['International_Sales_In_Dollar'], bins=50)
plt.show()
# Out:
# D:\APP\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#converting genre list to str
df['Genre'] = df['Genre'].apply(lambda x: x[1:-1])

# %%
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 6                                       Titanic (1997)
# 7                                Jurassic World (2015)
# ..                                                 ...
# 911                     While You Were Sleeping (1995)
# 913                                The Notebook (2004)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 6    A seventeen-year-old aristocrat falls in love ...
# ...

# %%
T = df.Genre.str.split(',',expand=True).iloc[:,0:2]
T.columns=['Genre1','Genre2']
T.Genre2.fillna(T.Genre1,inplace=True)
T
# Out:
#           Genre1        Genre2
# 0       'Action'   'Adventure'
# 1       'Action'   'Adventure'
# 2       'Action'   'Adventure'
# 6        'Drama'     'Romance'
# 7       'Action'   'Adventure'
# ..           ...           ...
# 911     'Comedy'       'Drama'
# 913      'Drama'     'Romance'
# 915  'Biography'       'Drama'
# 916      'Crime'      'Horror'
# 917     'Comedy'      'Family'
#
# [744 rows x 2 columns]

# %%
#concatenat T dataframe to main dataframe
df = pd.concat([df,T],axis=1)
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 6                                       Titanic (1997)
# 7                                Jurassic World (2015)
# ..                                                 ...
# 911                     While You Were Sleeping (1995)
# 913                                The Notebook (2004)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 6    A seventeen-year-old aristocrat falls in love ...
# ...

# %%
df.groupby(['Genre1','Genre2']).World_Sales_In_Dollar.mean().sort_values(ascending=False).head(5)
# Out:
# Genre1       Genre2
# 'Adventure'   'Family'       727.202815
# 'Horror'     'Horror'        701.796444
# 'Action'      'Adventure'    574.384065
# 'Adventure'   'Drama'        541.834024
# 'Mystery'     'Thriller'     527.406321
# Name: World_Sales_In_Dollar, dtype: float64

# %%
cmap = plt.get_cmap('Pastel1')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df.groupby(['Genre1','Genre2']).World_Sales_In_Dollar.mean().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(20,10), color=colors)

plt.title('Bar Chart showing Genre1,Genre2 on basis of world sales')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing Genre1,Genre2 on basis of world sales')

# %% [markdown]
# # We can infer that Adventure and Family type of Genre is mostly sale in the world

# %%
df.groupby(['Genre1','Genre2']).Domestic_Sales_In_Dollar.mean().sort_values(ascending=False).head(5)
# Out:
# Genre1       Genre2
# 'Horror'     'Horror'        328.828874
# 'Adventure'   'Family'       248.637018
# 'Action'      'Adventure'    220.782667
# 'Drama'       'War'          217.049603
# 'Comedy'      'Fantasy'      212.820484
# Name: Domestic_Sales_In_Dollar, dtype: float64

# %%
cmap = plt.get_cmap('Pastel1')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
ax = df.groupby(['Genre1','Genre2']).Domestic_Sales_In_Dollar.mean().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(20,10), color=colors)

plt.title('Bar Chart showing Genre1,Genre2 on basis of domestic sales')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing Genre1,Genre2 on basis of domestic sales')

# %% [markdown]
# # We can infer that Horror type of Genre is mostly saled domestically.

# %%
df.groupby(['Genre1','Genre2']).International_Sales_In_Dollar.mean().sort_values(ascending=False).head(5)
# Out:
# Genre1       Genre2
# 'Adventure'   'Family'       475.216040
# 'Horror'     'Horror'        372.967570
# 'Mystery'     'Thriller'     354.631785
# 'Action'      'Adventure'    353.083918
# 'Adventure'   'Drama'        342.088941
# Name: International_Sales_In_Dollar, dtype: float64

# %%
cmap = plt.get_cmap('Pastel1')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

import matplotlib.pyplot as plt
df.groupby(['Genre1','Genre2']).International_Sales_In_Dollar.mean().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(20,10), color=colors)

plt.title('Bar Chart showing Genre1,Genre2 on basis of International sales')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing Genre1,Genre2 on basis of International sales')

# %% [markdown]
# # We can infer that adventure and Family type of Genre is mostly saled Internationally.

# %% [markdown]
# # <center>END</center>
